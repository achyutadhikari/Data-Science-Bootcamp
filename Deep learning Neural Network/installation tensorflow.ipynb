# %%
import numpy as np

# %%
import tensorflow as tf

# %%
help('modules package')
# Out:
# Here is a list of modules whose name or summary contains 'package'.
# If there are any, enter a module name to get more help.
#
# asyncio - The asyncio package, tracking PEP 3156.
# distutils.versionpredicate - Module for parsing and testing package version predicate strings.
# email - A package for parsing, handling, and generating email messages.
# email._policybase - Policy framework for the email package.
# email.errors - email package exception classes.
# email.message - Basic message object for the email package object model.
# encodings - Standard "encodings" Package
# idlelib - The idlelib package implements the Idle application.
# lib2to3.pgen2 - The pgen2 package.
# logging - Logging package for Python. Based on PEP 282 and comments thereto in
# logging.config - Configuration functions for the logging package for Python. The core package
# logging.handlers - Additional handlers for the logging package for Python. The core package is
# ...

# %%
help('modules tensorflow')
# Out:
# Here is a list of modules whose name or summary contains 'tensorflow'.
# If there are any, enter a module name to get more help.
#
# opt_einsum.backends.tensorflow - Required functions for optimized contractions of numpy arrays using tensorflow.
# sympy.printing.tensorflow
# sympy.printing.tests.test_tensorflow
# tensorboard - TensorBoard is a webapp for understanding TensorFlow runs and graphs.
# tensorboard.compat.tensorflow_stub
# tensorboard.compat.tensorflow_stub.app - Generic entry point script.
# tensorboard.compat.tensorflow_stub.compat - Functions for Python 2 vs. 3 compatibility.
# tensorboard.compat.tensorflow_stub.compat.v1
# tensorboard.compat.tensorflow_stub.dtypes - Library of dtypes (Tensor element types).
# tensorboard.compat.tensorflow_stub.error_codes
# tensorboard.compat.tensorflow_stub.errors - Exception types for TensorFlow errors.
# tensorboard.compat.tensorflow_stub.flags - Import router for absl.flags.
# tensorboard.compat.tensorflow_stub.io
# ...

# %%
# !pip install tensorflow
