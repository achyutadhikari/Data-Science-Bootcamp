# %%
from absenteeism_module import *

# %%
# pd.read_csv('Absenteeism_data_new.csv')

# %%
model = absenteeism_model('model','scaler')

# %%
model.load_and_clean_data('Absenteeism_data_new.csv')

# %%
model.predicted_outputs()
# Out:
#      Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0           0         0         0         1            7
# 1           0         0         0         0            7
# 2           0         0         0         1            7
# 3           1         0         0         0            7
# 4           0         0         0         1            7
# ..        ...       ...       ...       ...          ...
# 695         1         0         0         0            5
# 696         1         0         0         0            5
# 697         1         0         0         0            5
# 698         0         0         0         1            5
# 699         0         0         0         1            5
#
#      Transportation Expense  Age  Body Mass Index  Education  Children  Pets  \
# 0                       289   33               30          0         2     1
# 1                       118   50               31          0         1     0
# ...
